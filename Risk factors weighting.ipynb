# %%
import numpy as np
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D

# %%
# Define the range for x and y
X = np.linspace(1, 5, 100)
Y = np.linspace(1, 5, 100)

# Create a grid of x and y values
X, Y = np.meshgrid(x, y)

# Calculate the function values for each combination of x and y
Z1 = (X+ Y)/2
Z2 = 5-((5-X)*(5-Y))**.5


# Create a 3D plot
# Increase the size of the figure by setting the figsize parameter
fig = plt.figure(figsize=(15, 15))  # Adjust the width and height as needed

ax = fig.add_subplot(111, projection='3d')

# Plot the surface
surf = ax.plot_surface(X, Y, Z1, cmap='RdYlGn_r')
#surf = ax.plot_surface(X, Y, Z2, cmap='RdYlGn_r')

# Add labels and title
ax.set_xlabel('Inherent risk')
ax.set_ylabel('Risk mitigant')
ax.set_zlabel('Net risk')
ax.set_title('Geometric vs simple average')

# Add a colorbar to the plot
fig.colorbar(surf)

# Show the plot
ax.view_init(elev=10, azim=-60)  # Set the elevation to 20 degrees and azimuth to 30 degrees
plt.show()

# %%
# Define the range for x and y
x = np.linspace(1, 5, 100)
y = np.linspace(1, 5, 100)

# Create a grid of x and y values
X, Y = np.meshgrid(x, y)

# Calculate the function values for each combination of x and y
Z1 = (X+ Y)/2
Z2 = 5-((5-X)*(5-Y))**.5


# Create a 3D plot
# Increase the size of the figure by setting the figsize parameter
fig = plt.figure(figsize=(15, 15))  # Adjust the width and height as needed

ax = fig.add_subplot(111, projection='3d')

# Plot the surface
surf = ax.plot_surface(X, Y, Z1, cmap='gray_r')
surf = ax.plot_surface(X, Y, Z2, cmap='RdYlGn_r')

# Add labels and title
ax.set_xlabel('Inherent risk')
ax.set_ylabel('Quality of the risk management')
ax.set_zlabel('Net risk')
ax.set_title('Geometric vs simple average')

# Add a colorbar to the plot
fig.colorbar(surf)

# Show the plot
ax.view_init(elev=15, azim=-60)  # Set the elevation to 20 degrees and azimuth to 30 degrees
plt.show()

# %%
# Define the range for x and y
x = np.linspace(1, 5, 100)
y = np.linspace(1, 5, 100)

# Create a grid of x and y values
X, Y = np.meshgrid(x, y)

# Calculate the function values for each combination of x and y
w_x=.1
w_y=1-w_x

Z1 = w_x*X+ w_y*Y
Z2 = 5-(5-X)**w_x*(5-Y)**w_y


# Create a 3D plot
# Increase the size of the figure by setting the figsize parameter
fig = plt.figure(figsize=(15, 15))  # Adjust the width and height as needed

ax = fig.add_subplot(111, projection='3d')

# Plot the surface
surf = ax.plot_surface(X, Y, Z1, cmap='gray_r')
surf = ax.plot_surface(X, Y, Z2, cmap='RdYlGn_r')

# Add labels and title
ax.set_xlabel('Inherent risk')
ax.set_ylabel('Quality of the risk management')
ax.set_zlabel('Net risk')
ax.set_title('Geometric vs simple average')

# Add a colorbar to the plot
fig.colorbar(surf)

# Show the plot
ax.view_init(elev=10, azim=-60)  # Set the elevation to 20 degrees and azimuth to 30 degrees
plt.show()

# %%
# Define the range for x and y
x = np.linspace(1, 5, 100)
y = np.linspace(1, 5, 100)

# Create a grid of x and y values
X, Y = np.meshgrid(x, y)

# Calculate the function values for each combination of x and y
Z1 = (X+ Y)/2
Z2 = 5.1-((5.1-X)*(5.1-Y))**.5-(0.5*(5.1-X)**.5*(5.1-Y)**(-.5))


# Create a 3D plot
# Increase the size of the figure by setting the figsize parameter
fig = plt.figure(figsize=(15, 15))  # Adjust the width and height as needed

ax = fig.add_subplot(111, projection='3d')

# Plot the surface
surf = ax.plot_surface(X, Y, Z1, cmap='gray_r')
surf = ax.plot_surface(X, Y, Z2, cmap='RdYlGn_r')

# Add labels and title
ax.set_xlabel('Inherent risk')
ax.set_ylabel('Quality of the risk management')
ax.set_zlabel('Net risk')
ax.set_title('Geometric vs simple average')

# Add a colorbar to the plot
fig.colorbar(surf)

# Show the plot
ax.view_init(elev=15, azim=-60)  # Set the elevation to 20 degrees and azimuth to 30 degrees
plt.show()
